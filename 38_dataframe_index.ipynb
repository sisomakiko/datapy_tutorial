# %% [markdown]
# # Index操作

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### .reset_index()で再度indexを割り振る

# %%
df = pd.read_csv('archive/tmdb_5000_movies.csv')
df[df['original_language'] == 'ja'].head(5)
# Out:
#         budget                                             genres homepage  \
# 97    15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...      NaN
# 1471  41677699  [{"id": 16, "name": "Animation"}, {"id": 10751...      NaN
# 1709  30000000  [{"id": 16, "name": "Animation"}, {"id": 878, ...      NaN
# 1987  24000000  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...      NaN
# 2247  26500000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...      NaN
#
#           id                                           keywords  \
# 97    315011  [{"id": 1299, "name": "monster"}, {"id": 7671,...
# 1471   12429  [{"id": 456, "name": "mother"}, {"id": 1357, "...
# 1709  192577                                                 []
# 1987    4935  [{"id": 334, "name": "flying"}, {"id": 616, "n...
# 2247     128  [{"id": 1721, "name": "fight"}, {"id": 1994, "...
#
#      original_language original_title  \
# 97                  ja         シン・ゴジラ
# 1471                ja        崖の上のポニョ
# ...

# %%
df = df[df['original_language'] == 'ja']

# %%
df.reset_index().head()
# Out:
#    index    budget                                             genres  \
# 0     97  15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   1471  41677699  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 2   1709  30000000  [{"id": 16, "name": "Animation"}, {"id": 878, ...
# 3   1987  24000000  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...
# 4   2247  26500000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#   homepage      id                                           keywords  \
# 0      NaN  315011  [{"id": 1299, "name": "monster"}, {"id": 7671,...
# 1      NaN   12429  [{"id": 456, "name": "mother"}, {"id": 1357, "...
# 2      NaN  192577                                                 []
# 3      NaN    4935  [{"id": 334, "name": "flying"}, {"id": 616, "n...
# 4      NaN     128  [{"id": 1721, "name": "fight"}, {"id": 1994, "...
#
#   original_language original_title  \
# 0                ja         シン・ゴジラ
# 1                ja        崖の上のポニョ
# ...

# %%
# もとのindexを上書きする場合
df = df.reset_index(drop=True)
df
# Out:
#       budget                                             genres  \
# 0   15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   41677699  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 2   30000000  [{"id": 16, "name": "Animation"}, {"id": 878, ...
# 3   24000000  [{"id": 14, "name": "Fantasy"}, {"id": 16, "na...
# 4   26500000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 5   20000000  [{"id": 16, "name": "Animation"}, {"id": 14, "...
# 6   15000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 7   12000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 8   12000000           [{"id": 878, "name": "Science Fiction"}]
# 9          0                      [{"id": 18, "name": "Drama"}]
# 10   8000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 11   5500000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 12  16000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13   1000000  [{"id": 12, "name": "Adventure"}, {"id": 27, "...
# ...

# %% [markdown]
# ## .set_index()

# %%
df = pd.read_csv('archive/tmdb_5000_movies.csv')
df.set_index('')
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...
